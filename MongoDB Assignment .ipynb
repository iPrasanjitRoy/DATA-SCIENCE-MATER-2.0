# %%
"""
Q1. What is MongoDB? Explain non-relational databases in short. In which scenarios it is preferred to use 
MongoDB over SQL databases?

MongoDB is a popular document-oriented NoSQL database. 
It is designed to store and manage unstructured and semi-structured data, such as JSON-like documents.



Non-relational Databases:
Non-relational databases, also known as NoSQL (Not Only SQL) databases, provide an alternative approach to data storage and management compared to traditional SQL databases.
Some key characteristics of non-relational databases include:


High Performance: Non-relational databases often prioritize performance and can handle large volumes of data and high write/read workloads.

Flexible Schema: Non-relational databases allow for dynamic and flexible schemas, meaning that each record or document can have a different structure or set of fields.





MongoDB, being a document-oriented NoSQL database, is preferred over SQL databases in certain scenarios:
Unstructured or Semi-structured Data: If your data is complex and doesn't fit neatly into a table-like structure, MongoDB's document model can efficiently handle unstructured or semi-structured data.


Horizontal Scalability: MongoDB's architecture supports easy scalability across multiple servers, making it suitable for applications that require high scalability and distribution of data.


It's important to note that the choice between MongoDB and SQL databases depends on the specific requirements of your application. 
SQL databases, with their structured schemas and rich query capabilities, may still be the preferred choice for applications that require complex relationships, ACID transactions, or extensive data integrity constraints.




"""

# %%
"""
Q2. State and Explain the features of MongoDB
MongoDB, a popular document-oriented NoSQL database, offers several key features that differentiate it from traditional SQL databases. 
Here are the important features of MongoDB:


Document Model:
MongoDB uses a flexible document model for data representation. Data is stored in JSON format.


Scalability and High Performance:
MongoDB is designed to scale horizontally by distributing data across multiple servers or clusters. 
It can handle large volumes of data and provides high throughput for both read and write operations. Sharding, replication, and auto-sharding features facilitate easy scalability and data distribution.


Integration with Programming Languages:
MongoDB provides native drivers and libraries for various programming languages, making it easy to integrate MongoDB with applications. 
It offers official drivers for popular languages like Python, Java, Node.js, and more. This wide range of language support makes MongoDB accessible and convenient for developers.


"""

# %%
"""
Q3. Write a code to connect MongoDB to Python. Also, create a database and a collection in MongoDB.

import pymongo 
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

uri = "mongodb+srv://prasanji:12345@cluster0.bxthqdz.mongodb.net/?retryWrites=true&w=majority"

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)



    
db = client['PWSkill']
data = {"name" : "Prasanjit",
        "Age" : 50,
        "Subject" : "DataScience"
        }

coll_PWSkill = db["My_Record"]

coll_PWSkill.insert_one(data) 


for i in coll_PWSkill.find_one({'name' : 'Prasanjit'}):
    print(i) 

    



"""

# %%
"""
# Q4. Using the database and the collection created in question number 3, write a code to insert one record, 
and insert many records. Use the find() and find_one() methods to print the inserted record.



db = client['PWSkill']
data = {"name" : "Prasanjit",
        "Age" : 50,
        "Subject" : "DataScience"
        }

coll_PWSkill = db["My_Record"]

coll_PWSkill.insert_one(data) 


for i in coll_PWSkill.find_one({'name' : 'Prasanjit'}):
    print(i) 

    


random = [
  {
    "id": 1,
    "name": "John Doe",
    "age": 30,
    "email": "johndoe@example.com",
    "address": "123 Main Street",
    "city": "New York",
    "state": "NY",
    "country": "USA"
  },
  {
    "id": 2,
    "name": "Jane Smith",
    "age": 35,
    "email": "janesmith@example.com",
    "address": "456 Elm Street",
    "city": "Los Angeles",
    "state": "CA",
    "country": "USA"
  },
  {
    "id": 3,
    "name": "Alex Johnson",
    "age": 25,
    "email": "alexjohnson@example.com",
    "address": "789 Oak Street",
    "city": "Chicago",
    "state": "IL",
    "country": "USA"
  }
]


coll_PWSkill.insert_many(random) 

for i in coll_PWSkill.find():
    print(i) 

for i in coll_PWSkill.find({'id' : {"$gte" :    2}}): 
    print(i) 


"""

# %%
"""
Q5. Explain how you can use the find() method to query the MongoDB database. Write a simple code to 
demonstrate this.


The find() method in MongoDB is used to query and retrieve documents from a collection based on specified criteria. 
It allows you to search for documents that match certain conditions or filters. 



Syntax: 
db.collection.find(query, projection)


import pymongo 
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

uri = "mongodb+srv://prasanji:12345@cluster0.bxthqdz.mongodb.net/?retryWrites=true&w=majority"

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)



    

random = [
  {
    "id": 1,
    "name": "John Doe",
    "age": 30,
    "email": "johndoe@example.com",
    "address": "123 Main Street",
    "city": "New York",
    "state": "NY",
    "country": "USA"
  },
  {
    "id": 2,
    "name": "Jane Smith",
    "age": 35,
    "email": "janesmith@example.com",
    "address": "456 Elm Street",
    "city": "Los Angeles",
    "state": "CA",
    "country": "USA"
  },
  {
    "id": 3,
    "name": "Alex Johnson",
    "age": 25,
    "email": "alexjohnson@example.com",
    "address": "789 Oak Street",
    "city": "Chicago",
    "state": "IL",
    "country": "USA"
  }
]


coll_PWSkill.insert_many(random) 

for i in coll_PWSkill.find():
    print(i) 

for i in coll_PWSkill.find({'id' : {"$gte" :    2}}): 
    print(i) 




"""

# %%
""""
Q6. Explain the sort() method. Give an example to demonstrate sorting in MongoDB.



The sort() method in MongoDB is used to sort the retrieved documents from a collection based on specified sorting criteria. 
It allows you to arrange the documents in ascending or descending order based on one or more fields.


Syntax:
db.collection.find(query).sort(sortingCriteria)


# I Have NOT Written Similar Code Again And Agin # COPY FROM Upper Question 
for i in coll_PWSkill.find().sort({age - 1}):  
    print(i) 


"""

# %%
"""
Q7. Explain why delete_one(), delete_many(), and drop() is used

delete_one():
The delete_one() method is used to delete a single document that matches a specified filter or criteria. It removes the first document that satisfies the given condition. 
If multiple documents match the criteria, only the first one encountered will be deleted.


delete_many():
The delete_many() method is used to delete multiple documents that match a specified filter or criteria. 
It removes all the documents that satisfy the given condition.

drop():
The drop() method is used to remove an entire collection from the database. 
It deletes the collection itself along with all the documents contained within it. 

"""
